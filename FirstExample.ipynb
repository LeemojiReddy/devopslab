# %% [markdown]
# <a href="https://colab.research.google.com/github/LeemojiReddy/devopslab/blob/main/FirstExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Leemoji Reddy This is about the Google Collab

# %%
print(1+2*5)
x=5
print(x)
# Out:
# 11
# 5

# %%
import pandas as pd
mylist=[10,20,40,50]
res=pd.Series(mylist)
print(res)
# Out:
# 0    10
# 1    20
# 2    40
# 3    50
# dtype: int64

# %%
import numpy as np
arr=np.array([1,2,3,4,4])
print(arr[2])
print(type(arr))
# Out:
# 3
# <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt
import numpy as np
xaxis=np.array([0,8])
yaxis=np.array([0,100])
plt.plot(xaxis,yaxis)
plt.show()
